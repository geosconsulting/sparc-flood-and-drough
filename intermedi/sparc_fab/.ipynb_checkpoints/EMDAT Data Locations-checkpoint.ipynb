# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine,MetaData

engine = create_engine(r'postgresql://geonode:geonode@localhost/geonode-imports')
connection = engine.connect()
schema_emdat = 'em_dat'

table_name = "sparc_emdat_Storm_THA"
try:
    df_emdat_paese = pd.read_sql_table(table_name, engine, index_col='disaster_no',schema= "em_dat")
    connection.close()
except Exception as tabella_non_esiste:
    print tabella_non_esiste.message
    
df_emdat_paese= df_emdat_paese.dropna(axis=1,how='any')
df_emdat_paese
# Out:
#              index        associated_dis       associated_dis2 country_name  \
# disaster_no
# 1962-0010        0                    --                    --     Thailand
# 1978-0260        1                    --                    --     Thailand
# 1981-0064        2                    --                    --     Thailand
# 1981-0104        3                    --                    --     Thailand
# 1989-0131        4                    --                    --     Thailand
# 1990-0409        5                    --                    --     Thailand
# 1991-0710        6                    --                    --     Thailand
# 1992-0201        7                    --                    --     Thailand
# 1992-0494        8                    --                    --     Thailand
# 1992-0495        9                    --                    --     Thailand
# 1992-0496       10                    --                    --     Thailand
# ...

# %%
df_emdat_paese_divisi = df_emdat_paese['location']
df_emdat_paese_divisi = df_emdat_paese_divisi.dropna(how='any')

# %%
locazioni_su_colonna = df_emdat_paese_divisi.str.split(",").apply(pd.Series, 1).stack()
locazioni_su_colonna.index = locazioni_su_colonna.index.droplevel(-1)

# %%
locazioni_su_colonna
# Out:
# disaster_no
# 1962-0010
# 1978-0260
# 1981-0064                          Nan province
# 1981-0104                                 South
# 1989-0131                              Chumphon
# 1989-0131                  Nakkhon Si Thammarat
# 1989-0131                           Phetchaburi
# 1989-0131                   Prachuap Khiri Khan
# 1989-0131                                Ranong
# 1989-0131                              Songkhla
# 1989-0131                 Surat Thani provinces
# 1990-0409    Central and northeastern Provinces
# 1991-0710                   North and Northeast
# 1992-0201
# 1992-0494       Ko Samui (Surat Thani province)
# 1992-0495              Sisaket province (North)
# 1992-0496                           Surat Thani
# 1992-0496                                 Krabi
# 1992-0496                              Phangnga
# 1992-0496         Nakhon Si Thammarat provinces
# 1993-0481                         Nakhon Phanom
# 1993-0481                          Sakon Nakhon
# ...

# %%
stringa = '2009-0047-192'
codice_temp = stringa.split('-')

# %%
codice = codice_temp[0] + "-" + codice_temp[1]
codice
# Out:
# '2009-0047'
